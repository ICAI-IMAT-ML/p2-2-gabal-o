# %% [markdown]
# # Laboratory practice 2.2: KNN classification
#
# Here we will implement our first ML model based on the _very_ popular KNN algorithm. We will use the preprocessed data from the previous practice, `SimData.dat`. The data should be properly cleaned already, and we should have available the two resulting files `train.dat` and `test.dat` with the training and testing data, respectively. Therefore, we will not need to do the preprocessing here, which is why we will (almost) jump to implementing KNN and applying it to the data.

# %%
# Load the modules you'll need later

# Plotting libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

# Data management libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Add Lab_2_2_kNN.py to the path
import sys
sys.path.append('../src')

# Import the functions from the solution
from Lab_2_2_kNN import knn, plot_probability_histograms, plot_roc_curve, evaluate_classification_metrics, plot_2Dmodel_predictions, plot_calibration_curve

# %% [markdown]
# ## 1. Prepare the Dataset

# %% [markdown]
# This part of the process you already did in the previous practice! You can reuse everything here. Moreover, if you saved the train/test split into `train.dat` and `test.dat`, you can use them here!

# %%
# Load the train and test data you generated (use the name "train_df" and "test_df")
train_df = pd.read_csv("../src/train.dat",delimiter="\t")
test_df = pd.read_csv("../src/test.dat",delimiter="\t")
# Convert output variable to factor
# TODO
train_df["Y"]=train_df["Y"].replace({"YES":"1","NO":"0"})
test_df["Y"]=test_df["Y"].replace({"YES":"1","NO":"0"})

# %%
# Define input and output variables, and store X_train, X_test, y_train and y_test matrices
input_vars = ['X1','X2']
target_var = 'Y'

X_train = train_df[input_vars]
y_train = train_df[target_var]
X_test = test_df[input_vars]
y_test = test_df[target_var]

# %% [markdown]
# ## 2. Training of Machine Learning models

# %% [markdown]
# #### Minkowski Distance

# %% [markdown]
# <center><img alt="minkowski distance" src="data:image/png;base64,..."/></center>

# %% [markdown]
# #### k-Nearest Neighbors Model

# %% [markdown]
# - [K-Nearest Neighbours](https://scikit-learn.org/stable/modules/neighbors.html#classification)
# - [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)

# %%
# Inputs of the model. Change accordingly to perform feature selection
INPUTS_KNN = input_vars

# Define hyperparameters of the model
k = 31 # Number of nearest neighbors
p = 2 # Order of Minkowski distance (what distance is this?)

# Create a model object
knn_fit = knn()
print(knn_fit)
# Out:
# kNN model (k=None, p=None)

# %%
# Train model
knn_fit.fit(X_train[INPUTS_KNN].values, y_train.values, k=k, p=p)
print("kNN Trained")
print(knn_fit)
# Out:
# kNN Trained
# kNN model (k=31, p=2)

# %%
model_predictions = plot_2Dmodel_predictions(X_train[INPUTS_KNN].values, y_train.values, knn_fit, 50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 model_predictions = plot_2Dmodel_predictions(X_train[INPUTS_KNN].values, y_train.values, knn_fit, 50)
#
# File c:\Users\gabal\Documents\IMAT 2\MACHINE LEARNING\p2-2-gabal-o\notebook\../src\Lab_2_2_kNN.py:217, in plot_2Dmodel_predictions(X, y, model, grid_points_n)
#     215 # # Predict on mesh grid
#     216 grid = np.c_[xx.ravel(), yy.ravel()]
# --> 217 probs = model.predict_proba(grid)[:, 1].reshape(xx.shape)
#     219 # Use Seaborn for the scatter plot
#     220 sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette="Set1", ax=ax[1])
#
# ValueError: cannot reshape array of size 1 into shape (50,50)

# %%
# Obtain train performance metrics
evaluate_classification_metrics(y_train, knn_fit.predict(X_train[INPUTS_KNN].values), 'YES')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Obtain train performance metrics
# ----> 2 evaluate_classification_metrics(y_train, knn_fit.predict(X_train[INPUTS_KNN].values), 'YES')
#
# File c:\Users\gabal\Documents\IMAT 2\MACHINE LEARNING\p2-2-gabal-o\notebook\../src\Lab_2_2_kNN.py:276, in evaluate_classification_metrics(y_true, y_pred, positive_label)
#     255 y_pred_mapped = np.array([1 if label == positive_label else 0 for label in y_pred])
#     257 # Confusion Matrix
#     258 # TODO
#     259
#    (...)
#     272 # F1 Score
#     273 # TODO
#     275 return {
# --> 276     "Confusion Matrix": [tn, fp, fn, tp],
#     277     "Accuracy": accuracy,
#     278     "Precision": precision,
#     279     "Recall": recall,
#     280     "Specificity": specificity,
#     281     "F1 Score": f1,
#     282 }
#
# NameError: name 'tn' is not defined

# %%
# Obtain test performance metrics
evaluate_classification_metrics(y_test, knn_fit.predict(X_test[INPUTS_KNN].values),  'YES')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Obtain test performance metrics
# ----> 2 evaluate_classification_metrics(y_test, knn_fit.predict(X_test[INPUTS_KNN].values),  'YES')
#
# File c:\Users\gabal\Documents\IMAT 2\MACHINE LEARNING\p2-2-gabal-o\notebook\../src\Lab_2_2_kNN.py:276, in evaluate_classification_metrics(y_true, y_pred, positive_label)
#     255 y_pred_mapped = np.array([1 if label == positive_label else 0 for label in y_pred])
#     257 # Confusion Matrix
#     258 # TODO
#     259
#    (...)
#     272 # F1 Score
#     273 # TODO
#     275 return {
# --> 276     "Confusion Matrix": [tn, fp, fn, tp],
#     277     "Accuracy": accuracy,
#     278     "Precision": precision,
#     279     "Recall": recall,
#     280     "Specificity": specificity,
#     281     "F1 Score": f1,
#     282 }
#
# NameError: name 'tn' is not defined

# %%
probs = knn_fit.predict_proba(X_train.values)

# %%
calibration_curve = plot_calibration_curve(y_train.values, probs[:,1], 'YES')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 calibration_curve = plot_calibration_curve(y_train.values, probs[:,1], 'YES')
#
# File c:\Users\gabal\Documents\IMAT 2\MACHINE LEARNING\p2-2-gabal-o\notebook\../src\Lab_2_2_kNN.py:310, in plot_calibration_curve(y_true, y_probs, positive_label, n_bins)
#     306 def plot_calibration_curve(y_true, y_probs, positive_label, n_bins=10):
#     307     """
#     308     Plot a calibration curve to evaluate the accuracy of predicted probabilities.
#     309
# --> 310     This function creates a plot that compares the mean predicted probabilities
#     311     in each bin with the fraction of positives (true outcomes) in that bin.
#     312     This helps assess how well the probabilities are calibrated.
#     313
#     314     Args:
#     315         y_true (array-like): True labels of the data. Can be binary or categorical.
#     316         y_probs (array-like): Predicted probabilities for the positive class (positive_label).
#     317                             Expected values are in the range [0, 1].
#     318         positive_label (int or str): The label that is considered the positive class.
#     319                                     This is used to map categorical labels to binary outcomes.
#     320         n_bins (int, optional): Number of bins to use for grouping predicted probabilities.
#     321                                 Defaults to 10. Bins are equally spaced in the range [0, 1].
#     322
#     323     Returns:
#     324         dict: A dictionary with the following keys:
#     325             - "bin_centers": Array of the center values of each bin.
#     326             - "true_proportions": Array of the fraction of positives in each bin
#     327
#     328     """
#     329         # Convert y_true to binary (0 or 1)
#     330     y_true_mapped = np.array([1 if label == positive_label else 0 for label in y_true])
#
# NameError: name 'bin_centers' is not defined

# %%
probability_histograms = plot_probability_histograms(y_train.values, probs[:,1], 'YES')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 probability_histograms = plot_probability_histograms(y_train.values, probs[:,1], 'YES')
#
# File c:\Users\gabal\Documents\IMAT 2\MACHINE LEARNING\p2-2-gabal-o\notebook\../src\Lab_2_2_kNN.py:342, in plot_probability_histograms(y_true, y_probs, positive_label, n_bins)
#     340     bin_mask = (y_probs >= bin_edges[i]) & (y_probs < bin_edges[i + 1])
#     341     bin_y_true = y_true_mapped[bin_mask]
# --> 342     true_proportions[i] = np.mean(bin_y_true) if len(bin_y_true) > 0 else 0  # Avoid NaN
#     345 plt.figure(figsize=(7, 5))
#     346 plt.plot(bin_centers, true_proportions, "o-", label="Calibration curve", color="blue")
#
# NameError: name 'y_true_mapped' is not defined

# %%
roc_curve = plot_roc_curve(y_train.values, probs[:,1], 'YES')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 roc_curve = plot_roc_curve(y_train.values, probs[:,1], 'YES')
#
# File c:\Users\gabal\Documents\IMAT 2\MACHINE LEARNING\p2-2-gabal-o\notebook\../src\Lab_2_2_kNN.py:370, in plot_roc_curve(y_true, y_probs, positive_label)
#     358 def plot_probability_histograms(y_true, y_probs, positive_label, n_bins=10):
#     359     """
#     360     Plot probability histograms for the positive and negative classes separately.
#     361
#     362     This function creates two histograms showing the distribution of predicted
#     363     probabilities for each class. This helps in understanding how the model
#     364     differentiates between the classes.
#     365
#     366     Args:
#     367         y_true (array-like): True labels of the data. Can be binary or categorical.
#     368         y_probs (array-like): Predicted probabilities for the positive class.
#     369                             Expected values are in the range [0, 1].
# --> 370         positive_label (int or str): The label considered as the positive class.
#     371                                     Used to map categorical labels to binary outcomes.
#     372         n_bins (int, optional): Number of bins for the histograms. Defaults to 10.
#     373                                 Bins are equally spaced in the range [0, 1].
#     374
#     375     Returns:
#     376         dict: A dictionary with the following keys:
#     377             - "array_passed_to_histogram_of_positive_class":
#     378                 Array of predicted probabilities for the positive class.
#     379             - "array_passed_to_histogram_of_negative_class":
#     380                 Array of predicted probabilities for the negative class.
#     381
#     382     """
#     383     y_true_mapped = np.array([1 if label == positive_label else 0 for label in y_true])
#     384     y_probs = np.array(y_probs)
#
# NameError: name 'fpr' is not defined
